# %%
import pandas as pd
import numpy as np
import networkx as nx
import json
import seaborn as sns
import matplotlib.pyplot as plt
import tweepy

# Download the data
json_data = pd.read_json('covid19_infodemic_english_data.json',lines=True)

json_data

# Removing uncessary columns
interaction_data = json_data.drop(columns=[
 'id_str',
 'full_text',
 'truncated',
 'display_text_range',
 'entities',
 'source',
 'in_reply_to_status_id',
 'in_reply_to_status_id_str',
 'in_reply_to_user_id',
 'in_reply_to_user_id_str',
 'in_reply_to_screen_name',
 'user',
 'geo',
 'coordinates',
 'place',
 'contributors',
 'is_quote_status',
 'lang',
 'quoted_status_id',
 'quoted_status_id_str',
 'quoted_status_permalink',
 'quoted_status',
 'possibly_sensitive',
 'extended_entities','favorited','retweeted'])

json_data
# Out:
#                    created_at                   id               id_str  \
# 0   2020-03-20 15:35:29+00:00  1241025578527903750  1241025578527903744
# 1   2020-03-19 02:36:13+00:00  1240467080954228737  1240467080954228736
# 2   2020-03-19 19:08:52+00:00  1240716889162018816  1240716889162018816
# 3   2020-03-20 18:02:16+00:00  1241062514886090754  1241062514886090752
# 4   2020-03-21 19:30:08+00:00  1241447017945223169  1241447017945223168
# ..                        ...                  ...                  ...
# 486 2020-03-06 07:35:56+00:00  1235831463121059840  1235831463121059840
# 487 2020-03-06 16:35:12+00:00  1235967176475111432  1235967176475111424
# 488 2020-03-06 22:28:55+00:00  1236056191324864515  1236056191324864512
# 489 2020-03-06 17:54:16+00:00  1235987075440283648  1235987075440283648
# 490 2020-03-06 16:04:56+00:00  1235959558058754048  1235959558058754048
#
#                                              full_text  truncated  \
# 0    For the average American the best way to tell ...      False
# 1     this is fucking bullshit https://t.co/lfLpuNg9GO      False
# 2    Can y’all please just follow the government’s ...      False
# 3    No offense but the corona virus disappearing b...      False
# 4    This is the face of someone who just spent 9 h...      False
# ..                                                 ...        ...
# 486  For example: When Trump invents numbers and ig...      False
# 487  President Trump's comments about the coronavir...      False
# 488  Drug companies reportedly killed a provision i...      False
# 489  Does @twitter have a team fighting covid-19 ru...      False
# 490  #FOX to cause PANDEMIC\n\n#FoxNews is spreadin...      False
#
#     display_text_range                                           entities  \
# 0             [0, 134]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1              [0, 24]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 218]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3              [0, 72]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4             [0, 268]  {'hashtags': [{'text': 'covid19', 'indices': [...
# ..                 ...                                                ...
# 486           [0, 276]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 487           [0, 247]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 488           [0, 276]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 489           [0, 273]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 490           [0, 278]  {'hashtags': [{'text': 'FOX', 'indices': [0, 4...
#
#                                                 source  in_reply_to_status_id  \
# 0    <a href="http://twitter.com/download/iphone" r...                    NaN
# 1    <a href="http://twitter.com/download/iphone" r...                    NaN
# 2    <a href="http://twitter.com/download/android" ...                    NaN
# 3    <a href="http://twitter.com/download/iphone" r...                    NaN
# 4    <a href="http://twitter.com/download/iphone" r...                    NaN
# ..                                                 ...                    ...
# 486  <a href="http://twitter.com/download/iphone" r...           1.235826e+18
# 487  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 488  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 489  <a href="http://twitter.com/download/iphone" r...                    NaN
# 490  <a href="http://twitter.com/#!/download/ipad" ...                    NaN
#
#      in_reply_to_status_id_str  ...  favorite_count  favorited retweeted lang  \
# 0                          NaN  ...          954568      False     False   en
# 1                          NaN  ...         1505405      False     False   en
# 2                          NaN  ...          660762      False     False   en
# 3                          NaN  ...          368883      False     False   en
# 4                          NaN  ...          445713      False     False   en
# ..                         ...  ...             ...        ...       ...  ...
# 486               1.235826e+18  ...             461      False     False   en
# 487                        NaN  ...             278      False     False   en
# 488                        NaN  ...             176      False     False   en
# 489                        NaN  ...             539      False     False   en
# 490                        NaN  ...             100      False     False   en
#
#      quoted_status_id  quoted_status_id_str  \
# 0                 NaN                   NaN
# 1        1.240119e+18          1.240119e+18
# 2                 NaN                   NaN
# 3        1.203561e+18          1.203561e+18
# 4                 NaN                   NaN
# ..                ...                   ...
# 486      1.233605e+18          1.233605e+18
# 487      1.235957e+18          1.235957e+18
# 488               NaN                   NaN
# 489               NaN                   NaN
# 490               NaN                   NaN
#
#                                quoted_status_permalink  \
# 0                                                  NaN
# 1    {'url': 'https://t.co/lfLpuNg9GO', 'expanded':...
# 2                                                  NaN
# 3    {'url': 'https://t.co/5BtaZrejD2', 'expanded':...
# 4                                                  NaN
# ..                                                 ...
# 486  {'url': 'https://t.co/mPcXvpQubG', 'expanded':...
# 487  {'url': 'https://t.co/WFtAdmK3rL', 'expanded':...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
#
#                                          quoted_status  possibly_sensitive  \
# 0                                                  NaN                 NaN
# 1    {'created_at': 'Wed Mar 18 03:31:09 +0000 2020...                 0.0
# 2                                                  NaN                 NaN
# 3    {'created_at': 'Sun Dec 08 06:24:59 +0000 2019...                 0.0
# 4                                                  NaN                 0.0
# ..                                                 ...                 ...
# 486  {'created_at': 'Sat Feb 29 04:09:36 +0000 2020...                 0.0
# 487  {'created_at': 'Fri Mar 06 15:53:49 +0000 2020...                 0.0
# 488                                                NaN                 0.0
# 489                                                NaN                 NaN
# 490                                                NaN                 0.0
#
#                                      extended_entities
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    {'media': [{'id': 1241447007669104648, 'id_str...
# ..                                                 ...
# 486                                                NaN
# 487                                                NaN
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
#
# [491 rows x 30 columns]

# %%
# Download the other dataset containing the questions
question_data = pd.read_csv('covid19_infodemic_english_data.tsv', delimiter='\t')
question_data
# Out:
#                 tweet_id                                               text  \
# 0    1241025578527903750  For the average American the best way to tell ...
# 1    1240467080954228737                           this is fucking bullshit
# 2    1240716889162018816  Can y’all please just follow the government’s ...
# 3    1241062514886090754  No offense but the corona virus disappearing b...
# 4    1241447017945223169  This is the face of someone who just spent 9 h...
# ..                   ...                                                ...
# 499  1235967176475111432  President Trump's comments about the coronavir...
# 500  1236056191324864515  Drug companies reportedly killed a provision i...
# 501  1235987075440283648  Does @twitter have a team fighting covid-19 ru...
# 502  1235959558058754048  #FOX to cause PANDEMIC  #FoxNews is spreading ...
# 503  1235985070009221120  NURTW Lagos is already sensitizing their peopl...
#
#     q1_label                                q2_label  \
# 0         no                                     NaN
# 1         no                                     NaN
# 2         no                                     NaN
# 3         no                                     NaN
# 4        yes    2_no_probably_contains_no_false_info
# ..       ...                                     ...
# 499      yes      4_yes_probably_contains_false_info
# 500      yes  1_no_definitely_contains_no_false_info
# 501       no                                     NaN
# 502      yes    2_no_probably_contains_no_false_info
# 503      yes                              3_not_sure
#
#                           q3_label                     q4_label  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4       4_yes_probably_of_interest  1_no_definitely_not_harmful
# ..                             ...                          ...
# 499     4_yes_probably_of_interest     5_yes_definitely_harmful
# 500     4_yes_probably_of_interest     5_yes_definitely_harmful
# 501                            NaN                          NaN
# 502     4_yes_probably_of_interest     5_yes_definitely_harmful
# 503  2_no_probably_not_of_interest       4_yes_probably_harmful
#
#             q5_label              q6_label               q7_label
# 0                NaN    no_joke_or_sarcasm     no_not_interesting
# 1                NaN        no_not_harmful     no_not_interesting
# 2                NaN        no_not_harmful     no_not_interesting
# 3                NaN        no_not_harmful     no_not_interesting
# 4     yes_not_urgent        no_not_harmful     no_not_interesting
# ..               ...                   ...                    ...
# 499   yes_not_urgent  yes_rumor_conspiracy     no_not_interesting
# 500   yes_not_urgent        no_not_harmful  yes_blame_authorities
# 501              NaN        no_not_harmful     no_not_interesting
# 502  yes_very_urgent        no_not_harmful     no_not_interesting
# 503   yes_not_urgent  yes_rumor_conspiracy     no_not_interesting
#
# [504 rows x 9 columns]

# %%
# Rename tweet id to use as merge index
interaction_data = interaction_data.rename(columns={'id': 'tweet_id'})
interaction_data
# Out:
#                    created_at             tweet_id  retweet_count  \
# 0   2020-03-20 15:35:29+00:00  1241025578527903750         187425
# 1   2020-03-19 02:36:13+00:00  1240467080954228737         333831
# 2   2020-03-19 19:08:52+00:00  1240716889162018816         160323
# 3   2020-03-20 18:02:16+00:00  1241062514886090754         154086
# 4   2020-03-21 19:30:08+00:00  1241447017945223169         126506
# ..                        ...                  ...            ...
# 486 2020-03-06 07:35:56+00:00  1235831463121059840            143
# 487 2020-03-06 16:35:12+00:00  1235967176475111432            168
# 488 2020-03-06 22:28:55+00:00  1236056191324864515            125
# 489 2020-03-06 17:54:16+00:00  1235987075440283648            179
# 490 2020-03-06 16:04:56+00:00  1235959558058754048            101
#
#      favorite_count
# 0            954568
# 1           1505405
# 2            660762
# 3            368883
# 4            445713
# ..              ...
# 486             461
# 487             278
# 488             176
# 489             539
# 490             100
#
# [491 rows x 4 columns]

# %%
# Merge the interaction data table with the question data table on shared 'tweet_id' index.
data = interaction_data.merge(question_data, how='inner', on='tweet_id')

# Rename misinformation question columns for easier use.
data = data.rename(columns={'q1_label': 'q1', 'q2_label': 'q2', 'q3_label': 'q3', 'q4_label': 'q4', 'q5_label': 'q5', 'q6_label': 'q6', 'q7_label': 'q7'})
data
# Out:
#                    created_at             tweet_id  retweet_count  \
# 0   2020-03-20 15:35:29+00:00  1241025578527903750         187425
# 1   2020-03-19 02:36:13+00:00  1240467080954228737         333831
# 2   2020-03-19 19:08:52+00:00  1240716889162018816         160323
# 3   2020-03-20 18:02:16+00:00  1241062514886090754         154086
# 4   2020-03-21 19:30:08+00:00  1241447017945223169         126506
# ..                        ...                  ...            ...
# 486 2020-03-06 07:35:56+00:00  1235831463121059840            143
# 487 2020-03-06 16:35:12+00:00  1235967176475111432            168
# 488 2020-03-06 22:28:55+00:00  1236056191324864515            125
# 489 2020-03-06 17:54:16+00:00  1235987075440283648            179
# 490 2020-03-06 16:04:56+00:00  1235959558058754048            101
#
#      favorite_count                                               text   q1  \
# 0            954568  For the average American the best way to tell ...   no
# 1           1505405                           this is fucking bullshit   no
# 2            660762  Can y’all please just follow the government’s ...   no
# 3            368883  No offense but the corona virus disappearing b...   no
# 4            445713  This is the face of someone who just spent 9 h...  yes
# ..              ...                                                ...  ...
# 486             461  For example: When Trump invents numbers and ig...   no
# 487             278  President Trump's comments about the coronavir...  yes
# 488             176  Drug companies reportedly killed a provision i...  yes
# 489             539  Does @twitter have a team fighting covid-19 ru...   no
# 490             100  #FOX to cause PANDEMIC  #FoxNews is spreading ...  yes
#
#                                          q2                          q3  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4      2_no_probably_contains_no_false_info  4_yes_probably_of_interest
# ..                                      ...                         ...
# 486                                     NaN                         NaN
# 487      4_yes_probably_contains_false_info  4_yes_probably_of_interest
# 488  1_no_definitely_contains_no_false_info  4_yes_probably_of_interest
# 489                                     NaN                         NaN
# 490    2_no_probably_contains_no_false_info  4_yes_probably_of_interest
#
#                               q4               q5                    q6  \
# 0                            NaN              NaN    no_joke_or_sarcasm
# 1                            NaN              NaN        no_not_harmful
# 2                            NaN              NaN        no_not_harmful
# 3                            NaN              NaN        no_not_harmful
# 4    1_no_definitely_not_harmful   yes_not_urgent        no_not_harmful
# ..                           ...              ...                   ...
# 486                          NaN              NaN        no_not_harmful
# 487     5_yes_definitely_harmful   yes_not_urgent  yes_rumor_conspiracy
# 488     5_yes_definitely_harmful   yes_not_urgent        no_not_harmful
# 489                          NaN              NaN        no_not_harmful
# 490     5_yes_definitely_harmful  yes_very_urgent        no_not_harmful
#
#                         q7
# 0       no_not_interesting
# 1       no_not_interesting
# 2       no_not_interesting
# 3       no_not_interesting
# 4       no_not_interesting
# ..                     ...
# 486     no_not_interesting
# 487     no_not_interesting
# 488  yes_blame_authorities
# 489     no_not_interesting
# 490     no_not_interesting
#
# [491 rows x 12 columns]

# %%
# Showcases the disparity between true and false tweets within the datasets
data['q1'].value_counts()
# Out:
# yes    299
# no     192
# Name: q1, dtype: int64

# %%
# Compare the average retweet count between those flagged verifiably fake or true
retweet_average = data.groupby('q1', as_index=False)['retweet_count'].mean()
retweet_average
# Out:
#     q1  retweet_count
# 0   no   25700.026042
# 1  yes   15163.347826

# %%
# Compare the average favorite count between those flagged verifiably fake or true
favorite_average = data.groupby('q1', as_index=False)['favorite_count'].mean()   
favorite_average
# Out:
#     q1  favorite_count
# 0   no    95456.151042
# 1  yes    55647.391304

# %%
# Create a sperate dataset with verifiable tweets.
verifiable_data = data[data.q1 != "no"]
verifiable_data
# Out:
#                    created_at             tweet_id  retweet_count  \
# 4   2020-03-21 19:30:08+00:00  1241447017945223169         126506
# 5   2020-03-22 08:06:20+00:00  1241637320325029889         128634
# 7   2020-03-23 17:13:35+00:00  1242137430322446344         119536
# 8   2020-03-19 19:09:28+00:00  1240717039377022977         141115
# 11  2020-03-19 16:28:40+00:00  1240676575168921600         100742
# ..                        ...                  ...            ...
# 484 2020-03-05 23:37:48+00:00  1235711139620753408            256
# 485 2020-03-05 16:14:52+00:00  1235599671571009536            486
# 487 2020-03-06 16:35:12+00:00  1235967176475111432            168
# 488 2020-03-06 22:28:55+00:00  1236056191324864515            125
# 490 2020-03-06 16:04:56+00:00  1235959558058754048            101
#
#      favorite_count                                               text   q1  \
# 4            445713  This is the face of someone who just spent 9 h...  yes
# 5            715158  Yesterday I knocked on my Tennant's door and t...  yes
# 7            331428  This is Dr. Usama Riaz. He spent past weeks sc...  yes
# 8            516085  fun fact: its tradition for europeans to sprea...  yes
# 11           322476  So, the last week I have been battling COVID-1...  yes
# ..              ...                                                ...  ...
# 484             776  Trump: Corona-flu is not serious, go to work i...  yes
# 485             414  But, but...Trump didn’t prepare for the corona...  yes
# 487             278  President Trump's comments about the coronavir...  yes
# 488             176  Drug companies reportedly killed a provision i...  yes
# 490             100  #FOX to cause PANDEMIC  #FoxNews is spreading ...  yes
#
#                                          q2                             q3  \
# 4      2_no_probably_contains_no_false_info     4_yes_probably_of_interest
# 5      2_no_probably_contains_no_false_info  2_no_probably_not_of_interest
# 7      2_no_probably_contains_no_false_info     4_yes_probably_of_interest
# 8      5_yes_definitely_contains_false_info     4_yes_probably_of_interest
# 11     2_no_probably_contains_no_false_info     4_yes_probably_of_interest
# ..                                      ...                            ...
# 484    2_no_probably_contains_no_false_info     4_yes_probably_of_interest
# 485      4_yes_probably_contains_false_info     4_yes_probably_of_interest
# 487      4_yes_probably_contains_false_info     4_yes_probably_of_interest
# 488  1_no_definitely_contains_no_false_info     4_yes_probably_of_interest
# 490    2_no_probably_contains_no_false_info     4_yes_probably_of_interest
#
#                               q4                       q5  \
# 4    1_no_definitely_not_harmful           yes_not_urgent
# 5    1_no_definitely_not_harmful      no_no_need_to_check
# 7    1_no_definitely_not_harmful  no_too_trivial_to_check
# 8         4_yes_probably_harmful      no_no_need_to_check
# 11     2_no_probably_not_harmful           yes_not_urgent
# ..                           ...                      ...
# 484     5_yes_definitely_harmful           yes_not_urgent
# 485     5_yes_definitely_harmful           yes_not_urgent
# 487     5_yes_definitely_harmful           yes_not_urgent
# 488     5_yes_definitely_harmful           yes_not_urgent
# 490     5_yes_definitely_harmful          yes_very_urgent
#
#                                                   q6  \
# 4                                     no_not_harmful
# 5                                     no_not_harmful
# 7                                     no_not_harmful
# 8    yes_xenophobic_racist_prejudices_or_hate_speech
# 11                                    no_not_harmful
# ..                                               ...
# 484                                   no_not_harmful
# 485                                   no_not_harmful
# 487                             yes_rumor_conspiracy
# 488                                   no_not_harmful
# 490                                   no_not_harmful
#
#                                   q7
# 4                 no_not_interesting
# 5                 no_not_interesting
# 7                 no_not_interesting
# 8    yes_classified_as_in_question_6
# 11             yes_blame_authorities
# ..                               ...
# 484            yes_blame_authorities
# 485               no_not_interesting
# 487               no_not_interesting
# 488            yes_blame_authorities
# 490               no_not_interesting
#
# [299 rows x 12 columns]

# %%
q2 = verifiable_data.sort_values(by=['q2'])

# %%
q3 = verifiable_data.sort_values(by=['q3'])

# %%
q4 = verifiable_data.sort_values(by=['q4'])

# %%
q5 = verifiable_data.sort_values(by=['q5'])

# %%
q6 = verifiable_data.sort_values(by=['q6'])

# %%
q7 = verifiable_data.sort_values(by=['q7'])

# %% [markdown]
# order=('1_no_definitely_contains_no_false_info', '2_no_probably_contains_no_false_info', '3_not_sure', '4_yes_probably_contains_false_info', '5_yes_definitely_contains_false_info')

# %%
# To what extent does the tweet appear to contain false information?
sns.barplot(x='retweet_count', y='q2', data=q2)
plt.xlabel("Retweet_Count")
plt.ylabel("Q2")
# Out:
# Text(0, 0.5, 'Q2')

# %%
# To what extent does the tweet appear to contain false information?
sns.barplot(x='favorite_count', y='q2', data=q2, orient='h')
plt.xlabel("Favorite")
plt.ylabel("Q2")
# Out:
# Text(0, 0.5, 'Q2')

# %%
sns.barplot(x='retweet_count', y='q3', data=q3, orient='h')
plt.xlabel("Retweet_Count")
plt.ylabel("Q3")
# Out:
# Text(0, 0.5, 'Q3')

# %%
sns.barplot(x='favorite_count', y='q3', data=q3, orient='h')
plt.xlabel("Favorite_Count")
plt.ylabel("Q3")
# Out:
# Text(0, 0.5, 'Q3')

# %%
sns.barplot(x='retweet_count', y='q4', data=q4, orient='h')
plt.xlabel("Retweet_Count")
plt.ylabel("Q4")
# Out:
# Text(0, 0.5, 'Q4')

# %%
sns.barplot(x='retweet_count', y='q5', data=q5, orient='h')
plt.xlabel("Retweet_Count")
plt.ylabel("Q5")
# Out:
# Text(0, 0.5, 'Q5')

# %%
sns.barplot(x='retweet_count', y='q6', data=q6, orient='h')
plt.xlabel("Retweet_Count")
plt.ylabel("Q6")
# Out:
# Text(0, 0.5, 'Q6')

# %%
sns.barplot(x='retweet_count', y='q7', data=q7, orient='h')
plt.xlabel("Retweet_Count")
plt.ylabel("Q7")
# Out:
# Text(0, 0.5, 'Q7')
